# %% [markdown]
# ## Document Loaders In LangChain

# %% [markdown]
# #### TextLoader

# %%
from langchain.document_loaders import TextLoader

loader = TextLoader("nvda_news_1.txt")
loader.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain.document_loaders import TextLoader
#       3 loader = TextLoader("nvda_news_1.txt")
#       4 loader.load()
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'

# %%
type(loader)
# Out:
# langchain.document_loaders.text.TextLoader

# %%
loader.file_path
# Out:
# 'nvda_news_1.txt'

# %% [markdown]
# #### CSVLoader

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.document_loaders.csv_loader import CSVLoader
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'

# %%
loader = CSVLoader(file_path="movies.csv")
data = loader.load()
data
# Out:
# [Document(page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR', metadata={'source': 'movies.csv', 'row': 0}),
#  Document(page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD', metadata={'source': 'movies.csv', 'row': 1}),
#  Document(page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD', metadata={'source': 'movies.csv', 'row': 2}),
#  Document(page_content='movie_id: 104\ntitle: Thor: Ragnarok\nindustry: Hollywood\nrelease_year: 2017\nimdb_rating: 7.9\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 180\nrevenue: 854\nunit: Millions\ncurrency: USD', metadata={'source': 'movies.csv', 'row': 3}),
#  Document(page_content='movie_id: 105\ntitle: Thor: Love and Thunder\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 250\nrevenue: 670\nunit: Millions\ncurrency: USD', metadata={'source': 'movies.csv', 'row': 4}),
#  Document(page_content='movie_id: 106\ntitle: Sholay\nindustry: Bollywood\nrelease_year: 1975\nimdb_rating: 8.1\nstudio: United Producers\nlanguage_id: 1\nbudget: Not Available\nrevenue: Not Available\nunit: Not Available\ncurrency: Not Available', metadata={'source': 'movies.csv', 'row': 5}),
#  Document(page_content='movie_id: 107\ntitle: Dilwale Dulhania Le Jayenge\nindustry: Bollywood\nrelease_year: 1995\nimdb_rating: 8\nstudio: Yash Raj Films\nlanguage_id: 1\nbudget: 400\nrevenue: 2000\nunit: Millions\ncurrency: INR', metadata={'source': 'movies.csv', 'row': 6}),
#  Document(page_content='movie_id: 108\ntitle: 3 Idiots\nindustry: Bollywood\nrelease_year: 2009\nimdb_rating: 8.4\nstudio: Vinod Chopra Films\nlanguage_id: 1\nbudget: 550\nrevenue: 4000\nunit: Millions\ncurrency: INR', metadata={'source': 'movies.csv', 'row': 7}),
#  Document(page_content='movie_id: 109\ntitle: Kabhi Khushi Kabhie Gham\nindustry: Bollywood\nrelease_year: 2001\nimdb_rating: 7.4\nstudio: Dharma Productions\nlanguage_id: 1\nbudget: 390\nrevenue: 1360\nunit: Millions\ncurrency: INR', metadata={'source': 'movies.csv', 'row': 8})]

# %%
data[0]
# Out:
# Document(page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR', metadata={'source': 'movies.csv', 'row': 0})

# %%
loader = CSVLoader(file_path="movies.csv", source_column="title")
data = loader.load()
data
# Out:
# [Document(page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR', metadata={'source': 'K.G.F: Chapter 2', 'row': 0}),
#  Document(page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD', metadata={'source': 'Doctor Strange in the Multiverse of Madness', 'row': 1}),
#  Document(page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD', metadata={'source': 'Thor: The Dark World', 'row': 2}),
#  Document(page_content='movie_id: 104\ntitle: Thor: Ragnarok\nindustry: Hollywood\nrelease_year: 2017\nimdb_rating: 7.9\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 180\nrevenue: 854\nunit: Millions\ncurrency: USD', metadata={'source': 'Thor: Ragnarok', 'row': 3}),
#  Document(page_content='movie_id: 105\ntitle: Thor: Love and Thunder\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 250\nrevenue: 670\nunit: Millions\ncurrency: USD', metadata={'source': 'Thor: Love and Thunder', 'row': 4}),
#  Document(page_content='movie_id: 106\ntitle: Sholay\nindustry: Bollywood\nrelease_year: 1975\nimdb_rating: 8.1\nstudio: United Producers\nlanguage_id: 1\nbudget: Not Available\nrevenue: Not Available\nunit: Not Available\ncurrency: Not Available', metadata={'source': 'Sholay', 'row': 5}),
#  Document(page_content='movie_id: 107\ntitle: Dilwale Dulhania Le Jayenge\nindustry: Bollywood\nrelease_year: 1995\nimdb_rating: 8\nstudio: Yash Raj Films\nlanguage_id: 1\nbudget: 400\nrevenue: 2000\nunit: Millions\ncurrency: INR', metadata={'source': 'Dilwale Dulhania Le Jayenge', 'row': 6}),
#  Document(page_content='movie_id: 108\ntitle: 3 Idiots\nindustry: Bollywood\nrelease_year: 2009\nimdb_rating: 8.4\nstudio: Vinod Chopra Films\nlanguage_id: 1\nbudget: 550\nrevenue: 4000\nunit: Millions\ncurrency: INR', metadata={'source': '3 Idiots', 'row': 7}),
#  Document(page_content='movie_id: 109\ntitle: Kabhi Khushi Kabhie Gham\nindustry: Bollywood\nrelease_year: 2001\nimdb_rating: 7.4\nstudio: Dharma Productions\nlanguage_id: 1\nbudget: 390\nrevenue: 1360\nunit: Millions\ncurrency: INR', metadata={'source': 'Kabhi Khushi Kabhie Gham', 'row': 8})]

# %%
data[0].page_content
# Out:
# 'movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'

# %%
data[0].metadata
# Out:
# {'source': 'K.G.F: Chapter 2', 'row': 0}

# %% [markdown]
# #### UnstructuredURLLoader

# %% [markdown]
# UnstructuredURLLoader of Langchain internally uses unstructured python library to load the content from url's
#
# https://unstructured-io.github.io/unstructured/introduction.html
#
# https://pypi.org/project/unstructured/#description

# %%
#installing necessary libraries, libmagic is used for file type detection
# !pip3 install unstructured libmagic python-magic python-magic-bin
# Out:
# Collecting unstructured
#   Downloading unstructured-0.25.2-py3-none-any.whl.metadata (30 kB)
# Collecting libmagic
#   Downloading libmagic-1.0.tar.gz (3.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting python-magic-bin
#   Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl.metadata (710 bytes)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured) (3.4.4)
# Collecting emoji<3.0.0,>=2.15.0 (from unstructured)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting filelock<4.0.0,>=3.12.0 (from unstructured)
#   Downloading filelock-3.32.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting html5lib<2.0.0,>=1.1 (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting installer<1.0.0,>=0.7.0 (from unstructured)
#   Downloading installer-0.7.0-py3-none-any.whl.metadata (936 bytes)
# Collecting langdetect<2.0.0,>=1.0.9 (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      ---------------------------------------- 981.5/981.5 kB 4.6 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting lxml<7.0.0,>=5.0.0 (from unstructured)
#   Downloading lxml-6.1.1-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting nh3<1.0.0,>=0.3.0 (from unstructured)
#   Downloading nh3-0.3.6-cp38-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting numba<1.0.0,>=0.60.0 (from unstructured)
#   Downloading numba-0.67.0-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured) (2.4.0)
# Collecting psutil<8.0.0,>=7.2.2 (from unstructured)
#   Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Collecting python-iso639<2027.0.0,>=2026.1.31 (from unstructured)
#   Downloading python_iso639-2026.7.23-py3-none-any.whl.metadata (15 kB)
# Collecting python-oxmsg<1.0.0,>=0.0.2 (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting rapidfuzz<4.0.0,>=3.14.3 (from unstructured)
#   Downloading rapidfuzz-3.14.5-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting regex<2027.0.0,>=2024.0.0 (from unstructured)
#   Downloading regex-2026.7.19-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured) (2.32.5)
# Collecting spacy<4.0.0,>=3.7.0 (from unstructured)
#   Downloading spacy-3.8.15-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Collecting tqdm<5.0.0,>=4.67.3 (from unstructured)
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured) (4.15.0)
# Collecting unstructured-client<1.0.0,>=0.25.9 (from unstructured)
#   Downloading unstructured_client-0.46.1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt<3.0.0,>=2.1.1 (from unstructured)
#   Downloading wrapt-2.3.0-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.8.1)
# Requirement already satisfied: six>=1.9 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.5.1)
# Collecting llvmlite<0.50,>=0.49.0dev0 (from numba<1.0.0,>=0.60.0->unstructured)
#   Downloading llvmlite-0.49.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: click in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.3.1)
# Collecting olefile (from python-oxmsg<1.0.0,>=0.0.2->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from requests<3.0.0,>=2.32.5->unstructured) (2025.11.12)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading murmurhash-1.0.15-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading cymem-2.0.13-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading preshed-3.0.13-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading thinc-8.3.13-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading srsly-2.5.3-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading typer-0.27.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.13.4)
# Requirement already satisfied: jinja2 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from spacy<4.0.0,>=3.7.0->unstructured) (25.0)
# Requirement already satisfied: colorama in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.4.4)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading blis-1.3.3-cp311-cp311-win_amd64.whl.metadata (7.7 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Collecting aiofiles>=25.1.0 (from unstructured-client<1.0.0,>=0.25.9->unstructured)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: httpcore>=1.0.9 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Collecting pypdf>=6.9.2 (from unstructured-client<1.0.0,>=0.25.9->unstructured)
#   Downloading pypdf-6.16.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting pypdfium2>=5.6.0 (from unstructured-client<1.0.0,>=0.25.9->unstructured)
#   Downloading pypdfium2-5.13.0-py3-none-win_amd64.whl.metadata (67 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open>=5.2.1 (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading smart_open-8.0.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: h11>=0.16 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.12.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Downloading unstructured-0.25.2-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.8 MB/s  0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ---------------------------------------- 0.0/608.4 kB ? eta -:--:--
#    ---------------------------------------- 608.4/608.4 kB 4.4 MB/s  0:00:00
# Downloading filelock-3.32.3-py3-none-any.whl (98 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading installer-0.7.0-py3-none-any.whl (453 kB)
# Downloading lxml-6.1.1-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.0 MB 4.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 4.4 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 3.9 MB/s  0:00:00
# Downloading nh3-0.3.6-cp38-abi3-win_amd64.whl (624 kB)
#    ---------------------------------------- 0.0/624.5 kB ? eta -:--:--
#    ---------------------------------------- 624.5/624.5 kB 4.6 MB/s  0:00:00
# Downloading numba-0.67.0-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 3.7 MB/s  0:00:00
# Downloading llvmlite-0.49.0-cp311-cp311-win_amd64.whl (41.9 MB)
#    ---------------------------------------- 0.0/41.9 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.9 MB 4.6 MB/s eta 0:00:09
#    - -------------------------------------- 1.8/41.9 MB 4.2 MB/s eta 0:00:10
#    -- ------------------------------------- 2.6/41.9 MB 4.1 MB/s eta 0:00:10
#    --- ------------------------------------ 3.4/41.9 MB 4.0 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.2/41.9 MB 4.0 MB/s eta 0:00:10
#    ---- ----------------------------------- 5.0/41.9 MB 4.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 6.0/41.9 MB 4.0 MB/s eta 0:00:10
#    ------ --------------------------------- 6.8/41.9 MB 4.0 MB/s eta 0:00:09
#    ------- -------------------------------- 7.6/41.9 MB 3.9 MB/s eta 0:00:09
#    -------- ------------------------------- 8.4/41.9 MB 3.9 MB/s eta 0:00:09
#    -------- ------------------------------- 9.2/41.9 MB 4.0 MB/s eta 0:00:09
#    --------- ------------------------------ 10.0/41.9 MB 3.9 MB/s eta 0:00:09
#    ---------- ----------------------------- 11.0/41.9 MB 3.9 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.8/41.9 MB 3.9 MB/s eta 0:00:08
#    ------------ --------------------------- 12.6/41.9 MB 3.9 MB/s eta 0:00:08
#    ------------ --------------------------- 13.4/41.9 MB 3.9 MB/s eta 0:00:08
#    ------------- -------------------------- 14.2/41.9 MB 3.9 MB/s eta 0:00:08
#    -------------- ------------------------- 14.9/41.9 MB 3.9 MB/s eta 0:00:07
#    --------------- ------------------------ 16.0/41.9 MB 3.9 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.8/41.9 MB 3.9 MB/s eta 0:00:07
#    ---------------- ----------------------- 17.6/41.9 MB 3.9 MB/s eta 0:00:07
#    ----------------- ---------------------- 18.4/41.9 MB 3.9 MB/s eta 0:00:07
#    ------------------ --------------------- 19.4/41.9 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 20.2/41.9 MB 3.9 MB/s eta 0:00:06
#    -------------------- ------------------- 21.0/41.9 MB 3.9 MB/s eta 0:00:06
#    -------------------- ------------------- 21.8/41.9 MB 3.9 MB/s eta 0:00:06
#    --------------------- ------------------ 22.5/41.9 MB 3.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 23.6/41.9 MB 3.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 24.4/41.9 MB 3.9 MB/s eta 0:00:05
#    ------------------------ --------------- 25.2/41.9 MB 3.9 MB/s eta 0:00:05
#    ------------------------ --------------- 26.0/41.9 MB 3.9 MB/s eta 0:00:05
#    ------------------------- -------------- 26.7/41.9 MB 3.9 MB/s eta 0:00:04
#    -------------------------- ------------- 27.5/41.9 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 28.3/41.9 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 28.8/41.9 MB 3.8 MB/s eta 0:00:04
#    ---------------------------- ----------- 29.9/41.9 MB 3.9 MB/s eta 0:00:04
#    ----------------------------- ---------- 30.7/41.9 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 31.5/41.9 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 32.5/41.9 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 33.3/41.9 MB 3.9 MB/s eta 0:00:03
#    -------------------------------- ------- 34.1/41.9 MB 3.9 MB/s eta 0:00:03
#    --------------------------------- ------ 34.9/41.9 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.9/41.9 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.7/41.9 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 37.5/41.9 MB 3.9 MB/s eta 0:00:02
#    ------------------------------------ --- 38.3/41.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 39.1/41.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 39.8/41.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  41.7/41.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  41.7/41.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 41.9/41.9 MB 3.8 MB/s  0:00:11
# Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl (137 kB)
# Downloading python_iso639-2026.7.23-py3-none-any.whl (167 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.14.5-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.4 MB/s  0:00:00
# Downloading regex-2026.7.19-cp311-cp311-win_amd64.whl (277 kB)
# Downloading spacy-3.8.15-cp311-cp311-win_amd64.whl (15.3 MB)
#    ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/15.3 MB 4.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/15.3 MB 3.6 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/15.3 MB 4.1 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/15.3 MB 3.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.2/15.3 MB 3.8 MB/s eta 0:00:03
#    ------------- -------------------------- 5.2/15.3 MB 4.0 MB/s eta 0:00:03
#    --------------- ------------------------ 6.0/15.3 MB 3.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.8/15.3 MB 3.9 MB/s eta 0:00:03
#    ------------------- -------------------- 7.3/15.3 MB 3.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------- -------------- 9.7/15.3 MB 3.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.7/15.3 MB 3.7 MB/s eta 0:00:02
#    ------------------------------ --------- 11.8/15.3 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.3 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.3 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 14.9/15.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.3/15.3 MB 3.6 MB/s  0:00:04
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp311-cp311-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp311-cp311-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp311-cp311-win_amd64.whl (122 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp311-cp311-win_amd64.whl (651 kB)
#    ---------------------------------------- 0.0/651.7 kB ? eta -:--:--
#    ---------------------------------------- 651.7/651.7 kB 5.0 MB/s  0:00:00
# Downloading thinc-8.3.13-cp311-cp311-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.8 MB/s  0:00:00
# Downloading blis-1.3.3-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.2 MB 5.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.8/6.2 MB 4.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.6/6.2 MB 4.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.4/6.2 MB 4.3 MB/s eta 0:00:01
#    --------------------------- ------------ 4.2/6.2 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  6.0/6.2 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 3.9 MB/s  0:00:01
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Downloading typer-0.27.1-py3-none-any.whl (122 kB)
# Downloading unstructured_client-0.46.1-py3-none-any.whl (169 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading wrapt-2.3.0-cp311-cp311-win_amd64.whl (80 kB)
# Downloading python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl (409 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Downloading pypdf-6.16.1-py3-none-any.whl (382 kB)
# Downloading pypdfium2-5.13.0-py3-none-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/3.9 MB 5.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/3.9 MB 4.4 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/3.9 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 3.9 MB/s  0:00:00
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-8.0.1-py3-none-any.whl (73 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Building wheels for collected packages: langdetect, libmagic
#   Building wheel for langdetect (pyproject.toml): started
#   Building wheel for langdetect (pyproject.toml): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993364 sha256=e242c5f03e9e6d86b01e0b581bcaa287d2b54225bc6710f35ac024d310ac7230
#   Stored in directory: c:\users\sasik\appdata\local\pip\cache\wheels\0a\f2\b2\e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for libmagic (pyproject.toml): started
#   Building wheel for libmagic (pyproject.toml): finished with status 'done'
#   Created wheel for libmagic: filename=libmagic-1.0-py3-none-any.whl size=4325 sha256=acb7b1c380f55edd2e48c6b59dbcd020d277803b56bb1b0ddbcce3153236b41d
#   Stored in directory: c:\users\sasik\appdata\local\pip\cache\wheels\3e\35\13\53c696ff5f3523479505ec5ed4156198671fb598fe678178bf
# Successfully built langdetect libmagic
# Installing collected packages: python-magic-bin, libmagic, filetype, wrapt, wasabi, tqdm, spacy-loggers, spacy-legacy, shellingham, regex, rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, psutil, olefile, nh3, murmurhash, mdurl, lxml, llvmlite, langdetect, installer, html5lib, filelock, emoji, cymem, confection, cloudpathlib, catalogue, blis, annotated-doc, aiofiles, srsly, smart-open, python-oxmsg, preshed, numba, markdown-it-py, unstructured-client, thinc, rich, typer, weasel, spacy, unstructured
#
#    - --------------------------------------  2/47 [filetype]
#    -- -------------------------------------  3/47 [wrapt]
#    --- ------------------------------------  4/47 [wasabi]
#    ---- -----------------------------------  5/47 [tqdm]
#    ---- -----------------------------------  5/47 [tqdm]
#    ----- ----------------------------------  6/47 [spacy-loggers]
#    ----- ----------------------------------  7/47 [spacy-legacy]
#    ----- ----------------------------------  7/47 [spacy-legacy]
#    ------- --------------------------------  9/47 [regex]
#    -------- ------------------------------- 10/47 [rapidfuzz]
#    -------- ------------------------------- 10/47 [rapidfuzz]
#    -------- ------------------------------- 10/47 [rapidfuzz]
#    ----------- ---------------------------- 13/47 [pypdfium2]
#    ----------- ---------------------------- 13/47 [pypdfium2]
#    ----------- ---------------------------- 13/47 [pypdfium2]
#    ----------- ---------------------------- 13/47 [pypdfium2]
#    ----------- ---------------------------- 14/47 [pypdf]
#    ----------- ---------------------------- 14/47 [pypdf]
#    ----------- ---------------------------- 14/47 [pypdf]
#    ----------- ---------------------------- 14/47 [pypdf]
#    ----------- ---------------------------- 14/47 [pypdf]
#   Attempting uninstall: psutil
#    ----------- ---------------------------- 14/47 [pypdf]
#     Found existing installation: psutil 7.2.1
#    ----------- ---------------------------- 14/47 [pypdf]
#     Uninstalling psutil-7.2.1:
#    ----------- ---------------------------- 14/47 [pypdf]
#       Successfully uninstalled psutil-7.2.1
#    ----------- ---------------------------- 14/47 [pypdf]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------ --------------------------- 15/47 [psutil]
#    ------------- -------------------------- 16/47 [olefile]
#    --------------- ------------------------ 18/47 [murmurhash]
#    ---------------- ----------------------- 19/47 [mdurl]
#    ----------------- ---------------------- 20/47 [lxml]
#    ----------------- ---------------------- 20/47 [lxml]
#    ----------------- ---------------------- 20/47 [lxml]
#    ----------------- ---------------------- 20/47 [lxml]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ----------------- ---------------------- 21/47 [llvmlite]
#    ------------------ --------------------- 22/47 [langdetect]
#    ------------------- -------------------- 23/47 [installer]
#    -------------------- ------------------- 24/47 [html5lib]
#    -------------------- ------------------- 24/47 [html5lib]
#    --------------------- ------------------ 25/47 [filelock]
#    --------------------- ------------------ 25/47 [filelock]
#    ---------------------- ----------------- 27/47 [cymem]
#    ------------------------ --------------- 29/47 [cloudpathlib]
#    ------------------------ --------------- 29/47 [cloudpathlib]
#    ------------------------- -------------- 30/47 [catalogue]
#    -------------------------- ------------- 31/47 [blis]
#    ---------------------------- ----------- 33/47 [aiofiles]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ---------------------------- ----------- 34/47 [srsly]
#    ----------------------------- ---------- 35/47 [smart-open]
#    ----------------------------- ---------- 35/47 [smart-open]
#    ------------------------------ --------- 36/47 [python-oxmsg]
#    ------------------------------- -------- 37/47 [preshed]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    -------------------------------- ------- 38/47 [numba]
#    --------------------------------- ------ 39/47 [markdown-it-py]
#    --------------------------------- ------ 39/47 [markdown-it-py]
#    --------------------------------- ------ 39/47 [markdown-it-py]
#    --------------------------------- ------ 39/47 [markdown-it-py]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 40/47 [unstructured-client]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ---------------------------------- ----- 41/47 [thinc]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ----------------------------------- ---- 42/47 [rich]
#    ------------------------------------ --- 43/47 [typer]
#    ------------------------------------ --- 43/47 [typer]
#    ------------------------------------- -- 44/47 [weasel]
#    ------------------------------------- -- 44/47 [weasel]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    -------------------------------------- - 45/47 [spacy]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------  46/47 [unstructured]
#    ---------------------------------------- 47/47 [unstructured]
#
# Successfully installed aiofiles-25.1.0 annotated-doc-0.0.5 blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 emoji-2.15.0 filelock-3.32.3 filetype-1.2.0 html5lib-1.1 installer-0.7.0 langdetect-1.0.9 libmagic-1.0 llvmlite-0.49.0 lxml-6.1.1 markdown-it-py-4.2.0 mdurl-0.1.2 murmurhash-1.0.15 nh3-0.3.6 numba-0.67.0 olefile-0.47 preshed-3.0.13 psutil-7.2.2 pypdf-6.16.1 pypdfium2-5.13.0 python-iso639-2026.7.23 python-magic-0.4.27 python-magic-bin-0.4.14 python-oxmsg-0.0.2 rapidfuzz-3.14.5 regex-2026.7.19 rich-15.0.0 shellingham-1.5.4 smart-open-8.0.1 spacy-3.8.15 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 tqdm-4.70.0 typer-0.27.1 unstructured-0.25.2 unstructured-client-0.46.1 wasabi-1.1.3 weasel-1.0.0 wrapt-2.3.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\sasik\AppData\Local\Programs\Python\Python311\Lib\site-packages\~sutil'.
#   You can safely remove it manually.

# %%
from langchain.document_loaders import UnstructuredURLLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from langchain.document_loaders import UnstructuredURLLoader
#
# ModuleNotFoundError: No module named 'langchain.document_loaders'

# %%
loader = UnstructuredURLLoader(
    urls = [
        "https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html",
        "https://www.moneycontrol.com/news/business/markets/market-corrects-post-rbi-ups-inflation-forecast-icrr-bet-on-these-top-10-rate-sensitive-stocks-ideas-11142611.html"
    ]
)

# %%
data = loader.load()
len(data)
# Out:
# 2

# %%
data[0].page_content[0:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data[0].page_content[0:100]
#
# NameError: name 'data' is not defined

# %%
data[0].metadata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data[0].metadata
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Text Splitters

# %% [markdown]
# Why do we need text splitters in first place?
#
# LLM's have token limits. Hence we need to split the text which can be large into small chunks so that each chunk size is under the token limit. There are various text splitter classes in langchain that allows us to do this.

# %%
# Taking some random text from wikipedia

text = """Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. 
It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. 
Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.

Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. 
Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. 
Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. 
Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.

Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. 
It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades."""

# %% [markdown]
# #### Manual approach of splitting the text into chunks

# %%
# Say LLM token limit is 100, in that case we can do simple thing such as this

text[0:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Say LLM token limit is 100, in that case we can do simple thing such as this
# ----> 3 text[0:100]
#
# NameError: name 'text' is not defined

# %%
# Well but we want complete words and want to do this for entire text, may be we can use Python's split funciton

words = text.split(" ")
len(words)
# Out:
# 264

# %%
chunks = []

s = ""
for word in words:
    s += word + " "
    if len(s)>200:
        chunks.append(s)
        s = ""
        
chunks.append(s)

# %%
chunks[:2]
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt ',
#  'Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in ']

# %% [markdown]
# **Splitting data into chunks can be done in native python but it is a tidious process. Also if necessary, you may need to experiment with various delimiters in an iterative manner to ensure that each chunk does not exceed the token length limit of the respective LLM.**
#
# **Langchain provides a better way through text splitter classes.**

# %% [markdown]
# #### Using Text Splitter Classes from Langchain
#
# #### CharacterTextSplitter

# %%
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size=200,
    chunk_overlap=0
)

# %%
chunks = splitter.split_text(text)
len(chunks)
# Out:
# Created a chunk of size 210, which is longer than the specified 200
# Created a chunk of size 208, which is longer than the specified 200
# Created a chunk of size 358, which is longer than the specified 200
# 9

# %%
for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 210
# 181
# 197
# 207
# 128
# 357
# 253

# %% [markdown]
# As you can see, all though we gave 200 as a chunk size since the split was based on \n, it ended up creating chunks that are bigger than size 200.

# %% [markdown]
# Another class from Langchain can be used to recursively split the text based on a list of separators. This class is RecursiveTextSplitter. Let's see how it works

# %% [markdown]
# #### RecursiveTextSplitter

# %%
text
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.\n\nBrothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. \nKip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. \nCinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. \nInterstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.\n\nInterstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. \nIt has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades.'

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

r_splitter = RecursiveCharacterTextSplitter(
    separators = ["\n\n", "\n", " "],  # List of separators based on requirement (defaults to ["\n\n", "\n", " "])
    chunk_size = 200,  # size of each chunk created
    chunk_overlap  = 0,  # size of  overlap between chunks in order to maintain the context
    length_function = len  # Function to calculate size, currently we are using "len" which denotes length of string however you can pass any token counter)
)

# %%
chunks = r_splitter.split_text(text)

for chunk in chunks:
    print(len(chunk))
# Out:
# 105
# 120
# 199
# 10
# 181
# 197
# 198
# 8
# 128
# 191
# 165
# 198
# 54

# %% [markdown]
# **Let's understand how exactly it formed these chunks**

# %%
first_split = text.split("\n\n")[0]
first_split
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. \nIt stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. \nSet in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.'

# %%
len(first_split)
# Out:
# 439

# %% [markdown]
# Recursive text splitter uses a list of separators, i.e.  separators = ["\n\n", "\n", "."]
#
# So now it will first split using \n\n and then if the resulting chunk size is greater than the chunk_size parameter which is 200
# in our case, then it will use the next separator which is \n

# %%
second_split = first_split.split("\n")
second_split
# Out:
# ['Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. ',
#  'It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. ',
#  'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.']

# %%
for split in second_split:
    print(len(split))
# Out:
# 106
# 121
# 210

# %% [markdown]
# Third split exceeds chunk size 200. Now it will further try to split that using the third separator which is ' ' (space)

# %%
second_split[2]
# Out:
# 'Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.'

# %% [markdown]
# When you split this using space (i.e. second_split[2].split(" ")), it will separate out each word and then it will merge those
# chunks such that their size is close to 200

# %% [markdown]
# <img src="chunk_size.jpg"/>
